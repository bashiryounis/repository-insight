# %% [markdown]
# ## Git Functionalty

# %%
import os
import pygit2
import asyncio

# %% [markdown]
# ## Clone repo

# %%
REPO_DIRS="./repos"

# %%
def clone_repository_sync(repo_url: str, destination: str):
    return pygit2.clone_repository(repo_url, destination)

async def clone_repo(repo_url: str):
    """Clone a Git repository using pygit2 into a designated directory for repositories."""
    repo_name = os.path.basename(repo_url.rstrip('/')).replace('.git', '')
    destination = os.path.join(REPO_DIRS, repo_name)
    os.makedirs(REPO_DIRS, exist_ok=True)
    
    try:
        # Run the blocking clone operation in a separate thread
        cloned_repo = await asyncio.get_running_loop().run_in_executor(
            None, clone_repository_sync, repo_url, destination
        )
        print(f"Repository cloned successfully to {destination}")
        return {
            "message": "Repository cloned successfully.",
            "repository_path": destination,
        }
    except Exception as e:
        print(f"Error cloning repository: {e}")

# %%
await clone_repo("https://github.com/bashiryounis/delivery-ocr.git")
# Out:
# Repository cloned successfully to ./repos/delivery-ocr
# {'message': 'Repository cloned successfully.',
#  'repository_path': './repos/delivery-ocr'}

# %% [markdown]
# ## Git Repo Tree

# %%
import os
import pygit2

repo_path = "./repos/delivery-ocr"
repo = pygit2.Repository(repo_path)

def traverse_tree(tree, parent_full_path):
    """
    Recursively traverse the pygit2 tree and return a list of node info dictionaries.
    The 'path' and 'parent_path' values are computed relative to the repository base.
    """
    nodes = []
    for entry in tree:
        # Compute the full path based on the parent's full path
        full_path = os.path.join(parent_full_path, entry.name)
        # Compute the relative path from the repository base
        relative_path = os.path.relpath(full_path, repo_path)
        # For the parent, compute its relative path as well
        relative_parent = os.path.relpath(parent_full_path, repo_path)
        if entry.filemode == pygit2.GIT_FILEMODE_TREE:
            # It's a folder
            nodes.append({
                "type": "folder",
                "name": entry.name,
                "path": relative_path,
                "parent_path": relative_parent
            })
            subtree = repo[entry.id]
            nodes.extend(traverse_tree(subtree, full_path))
        else:
            # It's a file; extract the extension
            _, ext = os.path.splitext(entry.name)
            nodes.append({
                "type": "file",
                "name": entry.name,
                "path": relative_path,
                "extension": ext.lstrip('.'),
                "parent_path": relative_parent
            })
    return nodes

# Get the HEAD commit and traverse its tree starting from repo_path (using repo_path as the full base)
head_commit = repo[repo.head.target]
repo_nodes = traverse_tree(head_commit.tree, repo_path)

print("Collected nodes from repository:")
for n in repo_nodes:
    print(n)
# Out:
# Collected nodes from repository:
# {'type': 'file', 'name': '.gitignore', 'path': '.gitignore', 'extension': '', 'parent_path': '.'}
# {'type': 'file', 'name': 'Makefile', 'path': 'Makefile', 'extension': '', 'parent_path': '.'}
# {'type': 'file', 'name': 'README.md', 'path': 'README.md', 'extension': 'md', 'parent_path': '.'}
# {'type': 'folder', 'name': 'api', 'path': 'api', 'parent_path': '.'}
# {'type': 'file', 'name': 'Dockerfile', 'path': 'api/Dockerfile', 'extension': '', 'parent_path': 'api'}
# {'type': 'file', 'name': 'dev_start.sh', 'path': 'api/dev_start.sh', 'extension': 'sh', 'parent_path': 'api'}
# {'type': 'file', 'name': 'poetry.lock', 'path': 'api/poetry.lock', 'extension': 'lock', 'parent_path': 'api'}
# {'type': 'file', 'name': 'pyproject.toml', 'path': 'api/pyproject.toml', 'extension': 'toml', 'parent_path': 'api'}
# {'type': 'folder', 'name': 'src', 'path': 'api/src', 'parent_path': 'api'}
# {'type': 'folder', 'name': 'core', 'path': 'api/src/core', 'parent_path': 'api/src'}
# {'type': 'file', 'name': 'config.py', 'path': 'api/src/core/config.py', 'extension': 'py', 'parent_path': 'api/src/core'}
# {'type': 'file', 'name': 'llm.py', 'path': 'api/src/core/llm.py', 'extension': 'py', 'parent_path': 'api/src/core'}
# {'type': 'file', 'name': 'logger_config.py', 'path': 'api/src/core/logger_config.py', 'extension': 'py', 'parent_path': 'api/src/core'}
# {'type': 'file', 'name': 'prompt.py', 'path': 'api/src/core/prompt.py', 'extension': 'py', 'parent_path': 'api/src/core'}
# {'type': 'file', 'name': 'schema.py', 'path': 'api/src/core/schema.py', 'extension': 'py', 'parent_path': 'api/src/core'}
# {'type': 'file', 'name': 'main.py', 'path': 'api/src/main.py', 'extension': 'py', 'parent_path': 'api/src'}
# {'type': 'folder', 'name': 'service', 'path': 'api/src/service', 'parent_path': 'api/src'}
# {'type': 'file', 'name': 'ocr_delivery.py', 'path': 'api/src/service/ocr_delivery.py', 'extension': 'py', 'parent_path': 'api/src/service'}
# {'type': 'file', 'name': 'utils.py', 'path': 'api/src/service/utils.py', 'extension': 'py', 'parent_path': 'api/src/service'}
# {'type': 'file', 'name': 'docker-compose.yaml', 'path': 'docker-compose.yaml', 'extension': 'yaml', 'parent_path': '.'}
# {'type': 'folder', 'name': 'docs', 'path': 'docs', 'parent_path': '.'}
# {'type': 'file', 'name': 'delivery_ocr.ipynb', 'path': 'docs/delivery_ocr.ipynb', 'extension': 'ipynb', 'parent_path': 'docs'}
# {'type': 'file', 'name': 'sample1.jpeg', 'path': 'docs/sample1.jpeg', 'extension': 'jpeg', 'parent_path': 'docs'}
# {'type': 'file', 'name': 'sample2.jpeg', 'path': 'docs/sample2.jpeg', 'extension': 'jpeg', 'parent_path': 'docs'}
# {'type': 'folder', 'name': 'main_dir', 'path': 'main_dir', 'parent_path': '.'}
# {'type': 'file', 'name': 'sample2.jpeg', 'path': 'main_dir/sample2.jpeg', 'extension': 'jpeg', 'parent_path': 'main_dir'}

# %% [markdown]
# ## Extract branches

# %%
def extract_branches(repo: pygit2.Repository):
    """
    Extract all local branches from the repo with their metadata.

    Returns:
        List of branch dicts, each with:
        - name
        - is_head (bool)
        - target_commit_hash
        - latest_commit_summary
        - latest_commit_time
        - commit_count
    """
    branches = []

    for ref_name in repo.references:
        if not ref_name.startswith("refs/heads/"):
            continue  # skip remote or tag references

        branch_name = ref_name.split("/")[-1]
        ref = repo.lookup_reference(ref_name)
        target = ref.target
        commit = repo[target]

        # Count number of commits in this branch
        commit_count = sum(1 for _ in repo.walk(target, pygit2.GIT_SORT_TIME))

        branches.append({
            "name": branch_name,
            "is_head": repo.head.shorthand == branch_name,
            "target_commit_hash": str(commit.id),
            "latest_commit_summary": commit.message.strip().split('\n')[0],
            "latest_commit_time": commit.commit_time,
            "commit_count": commit_count
        })

    return branches

# %%
repo_path = "./repos/delivery-ocr"
repo = pygit2.Repository(repo_path)

branches = extract_branches(repo)

for b in branches:
    print(f"Branch: {b['name']}")
    print(f"  Is HEAD?         {b['is_head']}")
    print(f"  Target Commit:   {b['target_commit_hash']}")
    print(f"  Summary:         {b['latest_commit_summary']}")
    print(f"  Commit Count:    {b['commit_count']}")
    print(f"  Last Updated At: {b['latest_commit_time']}")
# Out:
# Branch: main
#   Is HEAD?         True
#   Target Commit:   61b6f0a6af549f4b24b25dfd0ecb522cefa8d739
#   Summary:         - update port
#   Commit Count:    4
#   Last Updated At: 1744541659

# %% [markdown]
# ## Extract Commit History

# %%
import pygit2
from typing import List, Dict

def map_commits_to_branches(repo: pygit2.Repository) -> Dict[str, List[str]]:
    """
    Map each commit hash to the list of branches it appears in.
    """
    commit_branch_map = {}

    for ref_name in repo.references:
        if not ref_name.startswith("refs/heads/"):
            continue

        branch_name = ref_name.split("/")[-1]
        target = repo.lookup_reference(ref_name).target

        for commit in repo.walk(target, pygit2.GIT_SORT_TIME):
            h = str(commit.id)
            if h not in commit_branch_map:
                commit_branch_map[h] = []
            if branch_name not in commit_branch_map[h]:
                commit_branch_map[h].append(branch_name)

    return commit_branch_map


def extract_commits_with_diffs(repo: pygit2.Repository, max_count: int = 100):
    """
    Extract commits from all local branches with per-file diffs and associated branch names.
    
    Returns:
        commits: List of commit node dictionaries
        relationships: List of file-modification relationship dictionaries
    """
    commits = []
    relationships = []

    commit_branch_map = map_commits_to_branches(repo)
    visited = set()  # avoid duplicate commit processing

    for commit_hash, branches in commit_branch_map.items():
        commit = repo.revparse_single(commit_hash)
        if commit.id in visited:
            continue
        visited.add(commit.id)

        parents = commit.parents
        is_merge = len(parents) > 1

        if not parents:
            continue  # skip root commits

        parent = parents[0]
        diff = repo.diff(parent, commit)

        modified_files = []
        for patch in diff:
            file_path = patch.delta.new_file.path
            modified_files.append(file_path)

            # Build full patch
            diff_lines = []
            for hunk in patch.hunks:
                diff_lines.append(hunk.header)
                for line in hunk.lines:
                    prefix = line.origin  # '+', '-', ' '
                    content = line.content.strip('\n')
                    diff_lines.append(f"{prefix}{content}")

            file_diff_text = "\n".join(diff_lines)

            relationships.append({
                "commit_hash": str(commit.id),
                "file_path": file_path,
                "diff": file_diff_text
            })

        summary_diff = f"Files changed: {', '.join(modified_files)}"

        commits.append({
            "hash": str(commit.id),
            "summary": commit.message.strip().split('\n')[0],
            "message": commit.message.strip(),
            "author": {
                "name": commit.author.name,
                "email": commit.author.email,
                "time": commit.author.time
            },
            "committer": {
                "name": commit.committer.name,
                "email": commit.committer.email,
                "time": commit.committer.time
            },
            "parents": [str(p.id) for p in parents],
            "is_merge": is_merge,
            "branches": branches,
            "summary_diff": summary_diff
        })

        if len(commits) >= max_count:
            break

    return commits, relationships

# %%
repo_path = "./repos/delivery-ocr"
repo = pygit2.Repository(repo_path)

commits, modified_rels = extract_commits_with_diffs(repo, max_count=50)

for c in commits:
    print(f"{c['hash']} | branches: {c['branches']} | {c['summary_diff']}")

for r in modified_rels:
    print(f"{r['commit_hash']} modified {r['file_path']}")
# Out:
# 61b6f0a6af549f4b24b25dfd0ecb522cefa8d739 | branches: ['main'] | Files changed: docker-compose.yaml
# 0b99e1cb10c567aee329cc3833e7babaa45f17b0 | branches: ['main'] | Files changed: README.md
# cbd1055d6186163c39152e98dfccf2ee19495e9a | branches: ['main'] | Files changed: Makefile, README.md, api/Dockerfile, api/dev_start.sh, api/poetry.lock, api/pyproject.toml, api/src/core/config.py, api/src/core/llm.py, api/src/core/logger_config.py, api/src/core/prompt.py, api/src/core/schema.py, api/src/main.py, api/src/service/ocr_delivery.py, api/src/service/utils.py, docker-compose.yaml, docs/delivery_ocr.ipynb, docs/sample1.jpeg, docs/sample2.jpeg, main_dir/sample2.jpeg
# 61b6f0a6af549f4b24b25dfd0ecb522cefa8d739 modified docker-compose.yaml
# 0b99e1cb10c567aee329cc3833e7babaa45f17b0 modified README.md
# cbd1055d6186163c39152e98dfccf2ee19495e9a modified Makefile
# cbd1055d6186163c39152e98dfccf2ee19495e9a modified README.md
# cbd1055d6186163c39152e98dfccf2ee19495e9a modified api/Dockerfile
# cbd1055d6186163c39152e98dfccf2ee19495e9a modified api/dev_start.sh
# cbd1055d6186163c39152e98dfccf2ee19495e9a modified api/poetry.lock
# cbd1055d6186163c39152e98dfccf2ee19495e9a modified api/pyproject.toml
# cbd1055d6186163c39152e98dfccf2ee19495e9a modified api/src/core/config.py
# cbd1055d6186163c39152e98dfccf2ee19495e9a modified api/src/core/llm.py
# cbd1055d6186163c39152e98dfccf2ee19495e9a modified api/src/core/logger_config.py
# cbd1055d6186163c39152e98dfccf2ee19495e9a modified api/src/core/prompt.py
# cbd1055d6186163c39152e98dfccf2ee19495e9a modified api/src/core/schema.py
# cbd1055d6186163c39152e98dfccf2ee19495e9a modified api/src/main.py
# cbd1055d6186163c39152e98dfccf2ee19495e9a modified api/src/service/ocr_delivery.py
# cbd1055d6186163c39152e98dfccf2ee19495e9a modified api/src/service/utils.py
# cbd1055d6186163c39152e98dfccf2ee19495e9a modified docker-compose.yaml
# cbd1055d6186163c39152e98dfccf2ee19495e9a modified docs/delivery_ocr.ipynb
# cbd1055d6186163c39152e98dfccf2ee19495e9a modified docs/sample1.jpeg
# cbd1055d6186163c39152e98dfccf2ee19495e9a modified docs/sample2.jpeg
# cbd1055d6186163c39152e98dfccf2ee19495e9a modified main_dir/sample2.jpeg

# %% [markdown]
# ## Main Class

# %%
repo = pygit2.Repository(repo_path)


remote = repo.remotes["origin"]
print(f"[Remote]")
print(f"  Name : {remote.name}")
print(f"  URL  : {remote.url}")
# Out:
# [Remote]
#   Name : origin
#   URL  : https://github.com/bashiryounis/delivery-ocr.git
#   Fetch: ['+refs/heads/*:refs/remotes/origin/*']
#   Push : []

# %%
class GitRepoParser:
    def __init__(self, repo_path: str):
        self.repo_path = repo_path
        self.repo = pygit2.Repository(repo_path)
        self.nodes = {
            "metadata": {},
            "folders": [],
            "files": [],
            "branches": [],
            "commits": [],
        }

        self.relationship = {
            "parent": [],
            "modified": [],
        }
    
    def get_repo_metadata(self):
        """
        Extract and return repository metadata, including name, remote URL,
        default branch, and description. Populates self.nodes["metadata"].
        """
        remote_url = None
        repo_name = None

        try:
            remote = self.repo.remotes["origin"]
            if remote:
                remote_url = remote.url
                repo_name = os.path.splitext(os.path.basename(remote_url.rstrip("/")))[0]
                print(f"Repository remote URL: {remote_url}")
        except Exception as e:
            print(f"Failed to read remote origin: {e}")

        if not repo_name:
            repo_name = os.path.basename(os.path.abspath(self.repo_path))
            print(f"Fallback repository name from path: {repo_name}")

        try:
            default_branch = self.repo.head.shorthand
            print(f"Default branch: {default_branch}")
        except pygit2.GitError:
            default_branch = None
            print("No default branch found.")

        description_file = os.path.join(self.repo_path, ".git", "description")
        if os.path.exists(description_file):
            with open(description_file, "r") as f:
                description = f.read().strip()
                if description.strip().startswith("Unnamed repository; edit this file"):
                    description = "No description available"
        metadata = {
            "name": repo_name,
            "url": remote_url,
            "description": description,
            "default_branch": default_branch,
        }

        self.nodes["metadata"] = metadata
        return metadata
    
    def get_branches(self):
        """
        Return unified branch objects with optional remote tracking info.
        This avoids duplicating local/remote branches unless needed.
        """
        branch_dicts = []
        repo_name = self.nodes.get("metadata", {}).get("name", "unknown")

        for branch_name in self.repo.branches.local:
            try:
                branch_ref = self.repo.branches.local.get(branch_name)
                if not branch_ref:
                    continue

                commit = self.repo.get(branch_ref.target)

                # Tracking info
                is_tracking = False
                upstream_name = None
                remote_name = None

                try:
                    upstream = branch_ref.upstream
                    if upstream:
                        is_tracking = True
                        upstream_name = upstream.name
                        remote_name = upstream.remote_name
                except Exception:
                    pass

                # Latest commit ID
                commit_id = str(commit.id)

                # Count commits in branch
                commit_count = sum(1 for _ in self.repo.walk(commit.id, pygit2.GIT_SORT_TOPOLOGICAL))

                # Build branch object
                branch_dicts.append({
                    "name": branch_name,
                    "is_head": branch_ref.is_head(),
                    "is_default": branch_ref.is_head(),  # Treat HEAD as default in this context
                    "is_remote_tracking": is_tracking,
                    "upstream_name": upstream_name,
                    "remote_name": remote_name,
                    "latest_commit_id": commit_id,
                    "commit_count": commit_count,
                    "repo_name": repo_name,
                })

            except Exception as e:
                print(f"Failed to process branch '{branch_name}': {e}")

        self.nodes["branches"] = branch_dicts
        return branch_dicts

# %%
service = GitRepoParser(repo_path)
service.get_repo_metadata()
service.get_branches()
# Out:
# Repository remote URL: https://github.com/bashiryounis/delivery-ocr.git
# Default branch: main
# [{'name': 'main',
#   'is_head': True,
#   'is_default': True,
#   'is_remote_tracking': True,
#   'upstream_name': 'refs/remotes/origin/main',
#   'remote_name': 'origin',
#   'latest_commit_id': '61b6f0a6af549f4b24b25dfd0ecb522cefa8d739',
#   'commit_count': 4,
#   'repo_name': 'delivery-ocr'}]

# %% [markdown]
# ## build Basic KG in Neo4j

# %%
from neo4j import GraphDatabase, AsyncGraphDatabase
import asyncio

NEO4J_URI = "bolt://localhost:7687"
NEO4J_USERNAME="neo4j"
NEO4J_PASSWORD="passowrd"
# Define constants for node labels
REPO_LABEL = "Repository"
FOLDER_LABEL = "Folder"
FILE_LABEL = "File"


async def neo4j():
    driver = AsyncGraphDatabase.driver(
        NEO4J_URI, 
        auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

    await driver.close()  # close the driver object

# %%
import os
import pygit2

repo_path = "./repos/sec-insights"
repo = pygit2.Repository(repo_path)

def traverse_tree(tree, parent_full_path):
    """
    Recursively traverse the pygit2 tree and return a list of node info dictionaries.
    The 'path' and 'parent_path' values are computed relative to the repository base.
    """
    nodes = []
    for entry in tree:
        # Compute the full path based on the parent's full path
        full_path = os.path.join(parent_full_path, entry.name)
        # Compute the relative path from the repository base
        relative_path = os.path.relpath(full_path, repo_path)
        # For the parent, compute its relative path as well
        relative_parent = os.path.relpath(parent_full_path, repo_path)
        if entry.filemode == pygit2.GIT_FILEMODE_TREE:
            # It's a folder
            nodes.append({
                "type": "folder",
                "name": entry.name,
                "path": relative_path,
                "parent_path": relative_parent
            })
            subtree = repo[entry.id]
            nodes.extend(traverse_tree(subtree, full_path))
        else:
            # It's a file; extract the extension
            _, ext = os.path.splitext(entry.name)
            nodes.append({
                "type": "file",
                "name": entry.name,
                "path": relative_path,
                "extension": ext.lstrip('.'),
                "parent_path": relative_parent
            })
    return nodes

# Get the HEAD commit and traverse its tree starting from repo_path (using repo_path as the full base)
head_commit = repo[repo.head.target]
repo_nodes = traverse_tree(head_commit.tree, repo_path)

print("Collected nodes from repository:")
for n in repo_nodes:
    print(n)
# Out:
# Collected nodes from repository:
# {'type': 'folder', 'name': '.devcontainer', 'path': '.devcontainer', 'parent_path': '.'}
# {'type': 'file', 'name': 'Dockerfile', 'path': '.devcontainer/Dockerfile', 'extension': '', 'parent_path': '.devcontainer'}
# {'type': 'file', 'name': 'README.md', 'path': '.devcontainer/README.md', 'extension': 'md', 'parent_path': '.devcontainer'}
# {'type': 'file', 'name': 'devcontainer.json', 'path': '.devcontainer/devcontainer.json', 'extension': 'json', 'parent_path': '.devcontainer'}
# {'type': 'file', 'name': 'post_create_command.sh', 'path': '.devcontainer/post_create_command.sh', 'extension': 'sh', 'parent_path': '.devcontainer'}
# {'type': 'file', 'name': 'FAQ.md', 'path': 'FAQ.md', 'extension': 'md', 'parent_path': '.'}
# {'type': 'file', 'name': 'LICENSE', 'path': 'LICENSE', 'extension': '', 'parent_path': '.'}
# {'type': 'file', 'name': 'README.md', 'path': 'README.md', 'extension': 'md', 'parent_path': '.'}
# {'type': 'folder', 'name': 'backend', 'path': 'backend', 'parent_path': '.'}
# {'type': 'file', 'name': '.env.development', 'path': 'backend/.env.development', 'extension': 'development', 'parent_path': 'backend'}
# {'type': 'file', 'name': '.env.docker', 'path': 'backend/.env.docker', 'extension': 'docker', 'parent_path': 'backend'}
# {'type': 'file', 'name': '.flake8', 'path': 'backend/.flake8', 'extension': '', 'parent_path': 'backend'}
# {'type': 'file', 'name': '.gitignore', 'path': 'backend/.gitignore', 'extension': '', 'parent_path': 'backend'}
# {'type': 'file', 'name': '.pylintrc', 'path': 'backend/.pylintrc', 'extension': '', 'parent_path': 'backend'}
# {'type': 'file', 'name': '.python-version', 'path': 'backend/.python-version', 'extension': '', 'parent_path': 'backend'}
# {'type': 'folder', 'name': '.vscode', 'path': 'backend/.vscode', 'parent_path': 'backend'}
# {'type': 'file', 'name': 'settings.json', 'path': 'backend/.vscode/settings.json', 'extension': 'json', 'parent_path': 'backend/.vscode'}
# {'type': 'file', 'name': 'Dockerfile', 'path': 'backend/Dockerfile', 'extension': '', 'parent_path': 'backend'}
# {'type': 'file', 'name': 'Makefile', 'path': 'backend/Makefile', 'extension': '', 'parent_path': 'backend'}
# {'type': 'file', 'name': 'README.md', 'path': 'backend/README.md', 'extension': 'md', 'parent_path': 'backend'}
# {'type': 'file', 'name': 'alembic.ini', 'path': 'backend/alembic.ini', 'extension': 'ini', 'parent_path': 'backend'}
# {'type': 'folder', 'name': 'alembic', 'path': 'backend/alembic', 'parent_path': 'backend'}
# {'type': 'file', 'name': 'README', 'path': 'backend/alembic/README', 'extension': '', 'parent_path': 'backend/alembic'}
# {'type': 'file', 'name': 'env.py', 'path': 'backend/alembic/env.py', 'extension': 'py', 'parent_path': 'backend/alembic'}
# {'type': 'file', 'name': 'script.py.mako', 'path': 'backend/alembic/script.py.mako', 'extension': 'mako', 'parent_path': 'backend/alembic'}
# {'type': 'folder', 'name': 'versions', 'path': 'backend/alembic/versions', 'parent_path': 'backend/alembic'}
# {'type': 'file', 'name': '1b0b616e08c6_replace_value_within_.py', 'path': 'backend/alembic/versions/1b0b616e08c6_replace_value_within_.py', 'extension': 'py', 'parent_path': 'backend/alembic/versions'}
# {'type': 'file', 'name': '477cee72edc4_init_tables.py', 'path': 'backend/alembic/versions/477cee72edc4_init_tables.py', 'extension': 'py', 'parent_path': 'backend/alembic/versions'}
# {'type': 'file', 'name': '663b3fea3024_update_sub_process_columns.py', 'path': 'backend/alembic/versions/663b3fea3024_update_sub_process_columns.py', 'extension': 'py', 'parent_path': 'backend/alembic/versions'}
# {'type': 'file', 'name': '873c0c4616ea_add_foreign_key_indices.py', 'path': 'backend/alembic/versions/873c0c4616ea_add_foreign_key_indices.py', 'extension': 'py', 'parent_path': 'backend/alembic/versions'}
# {'type': 'file', 'name': '90a1d6a26343_create_doc_tables.py', 'path': 'backend/alembic/versions/90a1d6a26343_create_doc_tables.py', 'extension': 'py', 'parent_path': 'backend/alembic/versions'}
# {'type': 'file', 'name': 'c008bb4f3f48_update_sub_process_columns.py', 'path': 'backend/alembic/versions/c008bb4f3f48_update_sub_process_columns.py', 'extension': 'py', 'parent_path': 'backend/alembic/versions'}
# {'type': 'folder', 'name': 'app', 'path': 'backend/app', 'parent_path': 'backend'}
# {'type': 'file', 'name': '__init__.py', 'path': 'backend/app/__init__.py', 'extension': 'py', 'parent_path': 'backend/app'}
# {'type': 'folder', 'name': 'api', 'path': 'backend/app/api', 'parent_path': 'backend/app'}
# {'type': 'file', 'name': '__init__.py', 'path': 'backend/app/api/__init__.py', 'extension': 'py', 'parent_path': 'backend/app/api'}
# {'type': 'file', 'name': 'api.py', 'path': 'backend/app/api/api.py', 'extension': 'py', 'parent_path': 'backend/app/api'}
# {'type': 'file', 'name': 'crud.py', 'path': 'backend/app/api/crud.py', 'extension': 'py', 'parent_path': 'backend/app/api'}
# {'type': 'file', 'name': 'deps.py', 'path': 'backend/app/api/deps.py', 'extension': 'py', 'parent_path': 'backend/app/api'}
# {'type': 'folder', 'name': 'endpoints', 'path': 'backend/app/api/endpoints', 'parent_path': 'backend/app/api'}
# {'type': 'file', 'name': '__init__.py', 'path': 'backend/app/api/endpoints/__init__.py', 'extension': 'py', 'parent_path': 'backend/app/api/endpoints'}
# {'type': 'file', 'name': 'conversation.py', 'path': 'backend/app/api/endpoints/conversation.py', 'extension': 'py', 'parent_path': 'backend/app/api/endpoints'}
# {'type': 'file', 'name': 'documents.py', 'path': 'backend/app/api/endpoints/documents.py', 'extension': 'py', 'parent_path': 'backend/app/api/endpoints'}
# {'type': 'file', 'name': 'health.py', 'path': 'backend/app/api/endpoints/health.py', 'extension': 'py', 'parent_path': 'backend/app/api/endpoints'}
# {'type': 'folder', 'name': 'chat', 'path': 'backend/app/chat', 'parent_path': 'backend/app'}
# {'type': 'file', 'name': '__init__.py', 'path': 'backend/app/chat/__init__.py', 'extension': 'py', 'parent_path': 'backend/app/chat'}
# {'type': 'file', 'name': 'constants.py', 'path': 'backend/app/chat/constants.py', 'extension': 'py', 'parent_path': 'backend/app/chat'}
# {'type': 'file', 'name': 'engine.py', 'path': 'backend/app/chat/engine.py', 'extension': 'py', 'parent_path': 'backend/app/chat'}
# {'type': 'file', 'name': 'messaging.py', 'path': 'backend/app/chat/messaging.py', 'extension': 'py', 'parent_path': 'backend/app/chat'}
# {'type': 'file', 'name': 'pg_vector.py', 'path': 'backend/app/chat/pg_vector.py', 'extension': 'py', 'parent_path': 'backend/app/chat'}
# {'type': 'file', 'name': 'qa_response_synth.py', 'path': 'backend/app/chat/qa_response_synth.py', 'extension': 'py', 'parent_path': 'backend/app/chat'}
# {'type': 'file', 'name': 'tools.py', 'path': 'backend/app/chat/tools.py', 'extension': 'py', 'parent_path': 'backend/app/chat'}
# {'type': 'file', 'name': 'utils.py', 'path': 'backend/app/chat/utils.py', 'extension': 'py', 'parent_path': 'backend/app/chat'}
# {'type': 'folder', 'name': 'core', 'path': 'backend/app/core', 'parent_path': 'backend/app'}
# {'type': 'file', 'name': '__init__.py', 'path': 'backend/app/core/__init__.py', 'extension': 'py', 'parent_path': 'backend/app/core'}
# {'type': 'file', 'name': 'config.py', 'path': 'backend/app/core/config.py', 'extension': 'py', 'parent_path': 'backend/app/core'}
# {'type': 'folder', 'name': 'db', 'path': 'backend/app/db', 'parent_path': 'backend/app'}
# {'type': 'file', 'name': 'base.py', 'path': 'backend/app/db/base.py', 'extension': 'py', 'parent_path': 'backend/app/db'}
# {'type': 'file', 'name': 'session.py', 'path': 'backend/app/db/session.py', 'extension': 'py', 'parent_path': 'backend/app/db'}
# {'type': 'file', 'name': 'wait_for_db.py', 'path': 'backend/app/db/wait_for_db.py', 'extension': 'py', 'parent_path': 'backend/app/db'}
# {'type': 'file', 'name': 'loader_io.py', 'path': 'backend/app/loader_io.py', 'extension': 'py', 'parent_path': 'backend/app'}
# {'type': 'file', 'name': 'main.py', 'path': 'backend/app/main.py', 'extension': 'py', 'parent_path': 'backend/app'}
# {'type': 'folder', 'name': 'models', 'path': 'backend/app/models', 'parent_path': 'backend/app'}
# {'type': 'file', 'name': '__init__.py', 'path': 'backend/app/models/__init__.py', 'extension': 'py', 'parent_path': 'backend/app/models'}
# {'type': 'file', 'name': 'base.py', 'path': 'backend/app/models/base.py', 'extension': 'py', 'parent_path': 'backend/app/models'}
# {'type': 'file', 'name': 'db.py', 'path': 'backend/app/models/db.py', 'extension': 'py', 'parent_path': 'backend/app/models'}
# {'type': 'file', 'name': 'schema.py', 'path': 'backend/app/schema.py', 'extension': 'py', 'parent_path': 'backend/app'}
# {'type': 'file', 'name': 'docker-compose.yml', 'path': 'backend/docker-compose.yml', 'extension': 'yml', 'parent_path': 'backend'}
# {'type': 'file', 'name': 'localstack-cors-config.json', 'path': 'backend/localstack-cors-config.json', 'extension': 'json', 'parent_path': 'backend'}
# {'type': 'file', 'name': 'poetry.lock', 'path': 'backend/poetry.lock', 'extension': 'lock', 'parent_path': 'backend'}
# {'type': 'file', 'name': 'pyproject.toml', 'path': 'backend/pyproject.toml', 'extension': 'toml', 'parent_path': 'backend'}
# {'type': 'folder', 'name': 'scripts', 'path': 'backend/scripts', 'parent_path': 'backend'}
# {'type': 'file', 'name': 'build_vector_tables.py', 'path': 'backend/scripts/build_vector_tables.py', 'extension': 'py', 'parent_path': 'backend/scripts'}
# {'type': 'file', 'name': 'chat_llama.py', 'path': 'backend/scripts/chat_llama.py', 'extension': 'py', 'parent_path': 'backend/scripts'}
# {'type': 'file', 'name': 'dedupe_vector_store.py', 'path': 'backend/scripts/dedupe_vector_store.py', 'extension': 'py', 'parent_path': 'backend/scripts'}
# {'type': 'file', 'name': 'download_sec_pdf.py', 'path': 'backend/scripts/download_sec_pdf.py', 'extension': 'py', 'parent_path': 'backend/scripts'}
# {'type': 'file', 'name': 'file_utils.py', 'path': 'backend/scripts/file_utils.py', 'extension': 'py', 'parent_path': 'backend/scripts'}
# {'type': 'file', 'name': 'seed_db.py', 'path': 'backend/scripts/seed_db.py', 'extension': 'py', 'parent_path': 'backend/scripts'}
# {'type': 'file', 'name': 'seed_storage_context.py', 'path': 'backend/scripts/seed_storage_context.py', 'extension': 'py', 'parent_path': 'backend/scripts'}
# {'type': 'file', 'name': 'stock_utils.py', 'path': 'backend/scripts/stock_utils.py', 'extension': 'py', 'parent_path': 'backend/scripts'}
# {'type': 'file', 'name': 'upsert_db_sec_documents.py', 'path': 'backend/scripts/upsert_db_sec_documents.py', 'extension': 'py', 'parent_path': 'backend/scripts'}
# {'type': 'file', 'name': 'upsert_document.py', 'path': 'backend/scripts/upsert_document.py', 'extension': 'py', 'parent_path': 'backend/scripts'}
# {'type': 'folder', 'name': 'tests', 'path': 'backend/tests', 'parent_path': 'backend'}
# {'type': 'folder', 'name': 'app', 'path': 'backend/tests/app', 'parent_path': 'backend/tests'}
# {'type': 'folder', 'name': 'chat', 'path': 'backend/tests/app/chat', 'parent_path': 'backend/tests/app'}
# {'type': 'file', 'name': 'test_engine.py', 'path': 'backend/tests/app/chat/test_engine.py', 'extension': 'py', 'parent_path': 'backend/tests/app/chat'}
# {'type': 'file', 'name': 'troubleshooting.md', 'path': 'backend/troubleshooting.md', 'extension': 'md', 'parent_path': 'backend'}
# {'type': 'folder', 'name': 'frontend', 'path': 'frontend', 'parent_path': '.'}
# {'type': 'folder', 'name': '.devcontainer', 'path': 'frontend/.devcontainer', 'parent_path': 'frontend'}
# {'type': 'file', 'name': 'devcontainer.json', 'path': 'frontend/.devcontainer/devcontainer.json', 'extension': 'json', 'parent_path': 'frontend/.devcontainer'}
# {'type': 'file', 'name': '.env.example', 'path': 'frontend/.env.example', 'extension': 'example', 'parent_path': 'frontend'}
# {'type': 'file', 'name': '.eslintrc.cjs', 'path': 'frontend/.eslintrc.cjs', 'extension': 'cjs', 'parent_path': 'frontend'}
# {'type': 'file', 'name': '.gitignore', 'path': 'frontend/.gitignore', 'extension': '', 'parent_path': 'frontend'}
# {'type': 'file', 'name': 'README.md', 'path': 'frontend/README.md', 'extension': 'md', 'parent_path': 'frontend'}
# {'type': 'file', 'name': 'next.config.mjs', 'path': 'frontend/next.config.mjs', 'extension': 'mjs', 'parent_path': 'frontend'}
# {'type': 'file', 'name': 'package-lock.json', 'path': 'frontend/package-lock.json', 'extension': 'json', 'parent_path': 'frontend'}
# {'type': 'file', 'name': 'package.json', 'path': 'frontend/package.json', 'extension': 'json', 'parent_path': 'frontend'}
# {'type': 'file', 'name': 'postcss.config.cjs', 'path': 'frontend/postcss.config.cjs', 'extension': 'cjs', 'parent_path': 'frontend'}
# {'type': 'file', 'name': 'prettier.config.cjs', 'path': 'frontend/prettier.config.cjs', 'extension': 'cjs', 'parent_path': 'frontend'}
# {'type': 'folder', 'name': 'public', 'path': 'frontend/public', 'parent_path': 'frontend'}
# {'type': 'file', 'name': 'Gradient.png', 'path': 'frontend/public/Gradient.png', 'extension': 'png', 'parent_path': 'frontend/public'}
# {'type': 'file', 'name': 'chat-1.svg', 'path': 'frontend/public/chat-1.svg', 'extension': 'svg', 'parent_path': 'frontend/public'}
# {'type': 'file', 'name': 'chat-2.svg', 'path': 'frontend/public/chat-2.svg', 'extension': 'svg', 'parent_path': 'frontend/public'}
# {'type': 'file', 'name': 'chat-3.svg', 'path': 'frontend/public/chat-3.svg', 'extension': 'svg', 'parent_path': 'frontend/public'}
# {'type': 'file', 'name': 'chat-4.svg', 'path': 'frontend/public/chat-4.svg', 'extension': 'svg', 'parent_path': 'frontend/public'}
# {'type': 'file', 'name': 'chat-5.svg', 'path': 'frontend/public/chat-5.svg', 'extension': 'svg', 'parent_path': 'frontend/public'}
# {'type': 'file', 'name': 'citations.svg', 'path': 'frontend/public/citations.svg', 'extension': 'svg', 'parent_path': 'frontend/public'}
# {'type': 'file', 'name': 'doc-selector-no-highlight.svg', 'path': 'frontend/public/doc-selector-no-highlight.svg', 'extension': 'svg', 'parent_path': 'frontend/public'}
# {'type': 'file', 'name': 'docs-with-highlight.svg', 'path': 'frontend/public/docs-with-highlight.svg', 'extension': 'svg', 'parent_path': 'frontend/public'}
# {'type': 'file', 'name': 'favicon.ico', 'path': 'frontend/public/favicon.ico', 'extension': 'ico', 'parent_path': 'frontend/public'}
# {'type': 'file', 'name': 'full-chat.png', 'path': 'frontend/public/full-chat.png', 'extension': 'png', 'parent_path': 'frontend/public'}
# {'type': 'file', 'name': 'full-chat.svg', 'path': 'frontend/public/full-chat.svg', 'extension': 'svg', 'parent_path': 'frontend/public'}
# {'type': 'file', 'name': 'highlight-1.svg', 'path': 'frontend/public/highlight-1.svg', 'extension': 'svg', 'parent_path': 'frontend/public'}
# {'type': 'file', 'name': 'highlight-2.svg', 'path': 'frontend/public/highlight-2.svg', 'extension': 'svg', 'parent_path': 'frontend/public'}
# {'type': 'file', 'name': 'highlight-3.svg', 'path': 'frontend/public/highlight-3.svg', 'extension': 'svg', 'parent_path': 'frontend/public'}
# {'type': 'file', 'name': 'highlight-4.svg', 'path': 'frontend/public/highlight-4.svg', 'extension': 'svg', 'parent_path': 'frontend/public'}
# {'type': 'file', 'name': 'logo-black.svg', 'path': 'frontend/public/logo-black.svg', 'extension': 'svg', 'parent_path': 'frontend/public'}
# {'type': 'file', 'name': 'logo-white.svg', 'path': 'frontend/public/logo-white.svg', 'extension': 'svg', 'parent_path': 'frontend/public'}
# {'type': 'file', 'name': 'lyft-2021-10k.pdf', 'path': 'frontend/public/lyft-2021-10k.pdf', 'extension': 'pdf', 'parent_path': 'frontend/public'}
# {'type': 'file', 'name': 'multi-doc-1.svg', 'path': 'frontend/public/multi-doc-1.svg', 'extension': 'svg', 'parent_path': 'frontend/public'}
# {'type': 'file', 'name': 'multi-doc-2.svg', 'path': 'frontend/public/multi-doc-2.svg', 'extension': 'svg', 'parent_path': 'frontend/public'}
# {'type': 'file', 'name': 'multi-doc-3.svg', 'path': 'frontend/public/multi-doc-3.svg', 'extension': 'svg', 'parent_path': 'frontend/public'}
# {'type': 'file', 'name': 'multi-doc-4.svg', 'path': 'frontend/public/multi-doc-4.svg', 'extension': 'svg', 'parent_path': 'frontend/public'}
# {'type': 'file', 'name': 'uber-2021-10k.pdf', 'path': 'frontend/public/uber-2021-10k.pdf', 'extension': 'pdf', 'parent_path': 'frontend/public'}
# {'type': 'file', 'name': 'sentry.client.config.ts', 'path': 'frontend/sentry.client.config.ts', 'extension': 'ts', 'parent_path': 'frontend'}
# {'type': 'file', 'name': 'sentry.edge.config.ts', 'path': 'frontend/sentry.edge.config.ts', 'extension': 'ts', 'parent_path': 'frontend'}
# {'type': 'file', 'name': 'sentry.server.config.ts', 'path': 'frontend/sentry.server.config.ts', 'extension': 'ts', 'parent_path': 'frontend'}
# {'type': 'folder', 'name': 'src', 'path': 'frontend/src', 'parent_path': 'frontend'}
# {'type': 'folder', 'name': 'api', 'path': 'frontend/src/api', 'parent_path': 'frontend/src'}
# {'type': 'file', 'name': 'backend.tsx', 'path': 'frontend/src/api/backend.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/api'}
# {'type': 'folder', 'name': 'utils', 'path': 'frontend/src/api/utils', 'parent_path': 'frontend/src/api'}
# {'type': 'file', 'name': 'documents.tsx', 'path': 'frontend/src/api/utils/documents.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/api/utils'}
# {'type': 'folder', 'name': 'components', 'path': 'frontend/src/components', 'parent_path': 'frontend/src'}
# {'type': 'file', 'name': 'Layout.tsx', 'path': 'frontend/src/components/Layout.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/components'}
# {'type': 'folder', 'name': 'basics', 'path': 'frontend/src/components/basics', 'parent_path': 'frontend/src/components'}
# {'type': 'file', 'name': 'Loading.tsx', 'path': 'frontend/src/components/basics/Loading.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/components/basics'}
# {'type': 'file', 'name': 'Modal.tsx', 'path': 'frontend/src/components/basics/Modal.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/components/basics'}
# {'type': 'file', 'name': 'ModalPortal.tsx', 'path': 'frontend/src/components/basics/ModalPortal.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/components/basics'}
# {'type': 'folder', 'name': 'conversations', 'path': 'frontend/src/components/conversations', 'parent_path': 'frontend/src/components'}
# {'type': 'file', 'name': 'RenderConversations.tsx', 'path': 'frontend/src/components/conversations/RenderConversations.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/components/conversations'}
# {'type': 'folder', 'name': 'landing-page', 'path': 'frontend/src/components/landing-page', 'parent_path': 'frontend/src/components'}
# {'type': 'file', 'name': 'AnimateSvg.tsx', 'path': 'frontend/src/components/landing-page/AnimateSvg.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/components/landing-page'}
# {'type': 'file', 'name': 'MarketingSection.tsx', 'path': 'frontend/src/components/landing-page/MarketingSection.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/components/landing-page'}
# {'type': 'file', 'name': 'SelectTicker.tsx', 'path': 'frontend/src/components/landing-page/SelectTicker.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/components/landing-page'}
# {'type': 'file', 'name': 'TitleAndDropdown.tsx', 'path': 'frontend/src/components/landing-page/TitleAndDropdown.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/components/landing-page'}
# {'type': 'folder', 'name': 'modals', 'path': 'frontend/src/components/modals', 'parent_path': 'frontend/src/components'}
# {'type': 'file', 'name': 'ShareLinkModal.tsx', 'path': 'frontend/src/components/modals/ShareLinkModal.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/components/modals'}
# {'type': 'folder', 'name': 'pdf-viewer', 'path': 'frontend/src/components/pdf-viewer', 'parent_path': 'frontend/src/components'}
# {'type': 'file', 'name': 'DisplayMultiplePdfs.tsx', 'path': 'frontend/src/components/pdf-viewer/DisplayMultiplePdfs.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/components/pdf-viewer'}
# {'type': 'file', 'name': 'PdfOptionsBar.tsx', 'path': 'frontend/src/components/pdf-viewer/PdfOptionsBar.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/components/pdf-viewer'}
# {'type': 'file', 'name': 'ViewPdf.tsx', 'path': 'frontend/src/components/pdf-viewer/ViewPdf.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/components/pdf-viewer'}
# {'type': 'file', 'name': 'VirtualizedPdf.tsx', 'path': 'frontend/src/components/pdf-viewer/VirtualizedPdf.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/components/pdf-viewer'}
# {'type': 'file', 'name': 'pdfDisplayConstants.tsx', 'path': 'frontend/src/components/pdf-viewer/pdfDisplayConstants.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/components/pdf-viewer'}
# {'type': 'file', 'name': 'config.js', 'path': 'frontend/src/config.js', 'extension': 'js', 'parent_path': 'frontend/src'}
# {'type': 'file', 'name': 'constants.tsx', 'path': 'frontend/src/constants.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src'}
# {'type': 'folder', 'name': 'context', 'path': 'frontend/src/context', 'parent_path': 'frontend/src'}
# {'type': 'file', 'name': 'pdf.tsx', 'path': 'frontend/src/context/pdf.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/context'}
# {'type': 'file', 'name': 'env.mjs', 'path': 'frontend/src/env.mjs', 'extension': 'mjs', 'parent_path': 'frontend/src'}
# {'type': 'folder', 'name': 'hooks', 'path': 'frontend/src/hooks', 'parent_path': 'frontend/src'}
# {'type': 'file', 'name': 'useDocumentSelector.tsx', 'path': 'frontend/src/hooks/useDocumentSelector.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/hooks'}
# {'type': 'file', 'name': 'useMessages.tsx', 'path': 'frontend/src/hooks/useMessages.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/hooks'}
# {'type': 'file', 'name': 'useMultiplePdfs.tsx', 'path': 'frontend/src/hooks/useMultiplePdfs.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/hooks'}
# {'type': 'file', 'name': 'usePdfViewer.tsx', 'path': 'frontend/src/hooks/usePdfViewer.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/hooks'}
# {'type': 'folder', 'name': 'utils', 'path': 'frontend/src/hooks/utils', 'parent_path': 'frontend/src/hooks'}
# {'type': 'file', 'name': 'useFocus.tsx', 'path': 'frontend/src/hooks/utils/useFocus.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/hooks/utils'}
# {'type': 'file', 'name': 'useIsMobile.tsx', 'path': 'frontend/src/hooks/utils/useIsMobile.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/hooks/utils'}
# {'type': 'file', 'name': 'useLocalStorage.ts', 'path': 'frontend/src/hooks/utils/useLocalStorage.ts', 'extension': 'ts', 'parent_path': 'frontend/src/hooks/utils'}
# {'type': 'file', 'name': 'useModal.tsx', 'path': 'frontend/src/hooks/utils/useModal.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/hooks/utils'}
# {'type': 'file', 'name': 'useScrollBreakpoint.tsx', 'path': 'frontend/src/hooks/utils/useScrollBreakpoint.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/hooks/utils'}
# {'type': 'folder', 'name': 'modules', 'path': 'frontend/src/modules', 'parent_path': 'frontend/src'}
# {'type': 'file', 'name': 'react-pdf.d.ts', 'path': 'frontend/src/modules/react-pdf.d.ts', 'extension': 'ts', 'parent_path': 'frontend/src/modules'}
# {'type': 'folder', 'name': 'pages', 'path': 'frontend/src/pages', 'parent_path': 'frontend/src'}
# {'type': 'file', 'name': '_app.tsx', 'path': 'frontend/src/pages/_app.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/pages'}
# {'type': 'file', 'name': '_document.tsx', 'path': 'frontend/src/pages/_document.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/pages'}
# {'type': 'file', 'name': '_error.tsx', 'path': 'frontend/src/pages/_error.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/pages'}
# {'type': 'folder', 'name': 'conversation', 'path': 'frontend/src/pages/conversation', 'parent_path': 'frontend/src/pages'}
# {'type': 'file', 'name': '[id].tsx', 'path': 'frontend/src/pages/conversation/[id].tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/pages/conversation'}
# {'type': 'file', 'name': 'index.tsx', 'path': 'frontend/src/pages/index.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/pages'}
# {'type': 'folder', 'name': 'styles', 'path': 'frontend/src/styles', 'parent_path': 'frontend/src'}
# {'type': 'file', 'name': 'globals.css', 'path': 'frontend/src/styles/globals.css', 'extension': 'css', 'parent_path': 'frontend/src/styles'}
# {'type': 'file', 'name': 'react-select.tsx', 'path': 'frontend/src/styles/react-select.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/styles'}
# {'type': 'folder', 'name': 'svgs', 'path': 'frontend/src/svgs', 'parent_path': 'frontend/src'}
# {'type': 'file', 'name': 'llama.tsx', 'path': 'frontend/src/svgs/llama.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/svgs'}
# {'type': 'file', 'name': 'right-arrow.tsx', 'path': 'frontend/src/svgs/right-arrow.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/svgs'}
# {'type': 'folder', 'name': 'types', 'path': 'frontend/src/types', 'parent_path': 'frontend/src'}
# {'type': 'folder', 'name': 'backend', 'path': 'frontend/src/types/backend', 'parent_path': 'frontend/src/types'}
# {'type': 'file', 'name': 'document.tsx', 'path': 'frontend/src/types/backend/document.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/types/backend'}
# {'type': 'file', 'name': 'conversation.tsx', 'path': 'frontend/src/types/conversation.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/types'}
# {'type': 'file', 'name': 'document.tsx', 'path': 'frontend/src/types/document.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/types'}
# {'type': 'file', 'name': 'selection.tsx', 'path': 'frontend/src/types/selection.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/types'}
# {'type': 'folder', 'name': 'utils', 'path': 'frontend/src/utils', 'parent_path': 'frontend/src'}
# {'type': 'file', 'name': 'colors.tsx', 'path': 'frontend/src/utils/colors.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/utils'}
# {'type': 'file', 'name': 'documents.tsx', 'path': 'frontend/src/utils/documents.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/utils'}
# {'type': 'file', 'name': 'landing-page-selection.tsx', 'path': 'frontend/src/utils/landing-page-selection.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/utils'}
# {'type': 'file', 'name': 'multi-line-highlight.tsx', 'path': 'frontend/src/utils/multi-line-highlight.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/utils'}
# {'type': 'file', 'name': 'timezone.tsx', 'path': 'frontend/src/utils/timezone.tsx', 'extension': 'tsx', 'parent_path': 'frontend/src/utils'}
# {'type': 'file', 'name': 'tailwind.config.ts', 'path': 'frontend/tailwind.config.ts', 'extension': 'ts', 'parent_path': 'frontend'}
# {'type': 'file', 'name': 'tsconfig.json', 'path': 'frontend/tsconfig.json', 'extension': 'json', 'parent_path': 'frontend'}
# {'type': 'file', 'name': 'render.yaml', 'path': 'render.yaml', 'extension': 'yaml', 'parent_path': '.'}

# %%
async def create_repository_node(session, name):
    query = (
        f"MERGE (r:{REPO_LABEL} {{ name: $name }}) "
        "RETURN r"
    )
    result = await session.run(query, name=name)
    record = await result.single()
    return record["r"]

# %%
async def create_folder_node(session, name, path, parent_path):
    if parent_path == ".":
        query = (
            f"MERGE (f:{FOLDER_LABEL} {{ path: $path }}) "
            "SET f.name = $name "
            "WITH f "
            f"MATCH (p:{REPO_LABEL} {{ name: $repo_name }}) "  # only double braces
            "MERGE (p)-[:CONTAINS]->(f) "
            "RETURN f"
        )
        result = await session.run(query, name=name, path=path, repo_name="sec-insights")
    else:
        query = (
            f"MERGE (f:{FOLDER_LABEL} {{ path: $path }}) "
            "SET f.name = $name "
            "WITH f "
            f"MATCH (p:{FOLDER_LABEL} {{ path: $parent_path }}) "  
            "MERGE (p)-[:CONTAINS]->(f) "
            "RETURN f"
        )
        result = await session.run(query, name=name, path=path, parent_path=parent_path)
    record = await result.single()
    return record["f"]

async def create_file_node(session, name, path, extension, parent_path):
    if parent_path == ".":
        query = (
            f"MERGE (f:{FILE_LABEL} {{ path: $path }}) "
            "SET f.name = $name, f.extension = $extension "
            "WITH f "
            f"MATCH (p:{REPO_LABEL} {{ name: $repo_name }}) "  
            "MERGE (p)-[:CONTAINS]->(f) "
            "RETURN f"
        )
        result = await session.run(query, name=name, path=path, extension=extension, repo_name="sec-insights")
    else:
        query = (
            f"MERGE (f:{FILE_LABEL} {{ path: $path }}) "
            "SET f.name = $name, f.extension = $extension "
            "WITH f "
            f"MATCH (p:{FOLDER_LABEL} {{ path: $parent_path }}) "  
            "MERGE (p)-[:CONTAINS]->(f) "
            "RETURN f"
        )
        result = await session.run(query, name=name, path=path, extension=extension, parent_path=parent_path)
    record = await result.single()
    return record["f"]

# %%
driver = AsyncGraphDatabase.driver(
    NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD)
)
driver = AsyncGraphDatabase.driver(
        NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD)
    )

async with driver.session() as session:
    # Create the repository node with just a name
    repo_node = await create_repository_node(session, "sec-insights")
    print("Created Repository Node:", repo_node)
    
    # Create folder and file nodes using the collected repository tree data
    for node in repo_nodes:
        if node["type"] == "folder":
            folder_node = await create_folder_node(
                session, node["name"], node["path"], node["parent_path"]
            )
            print("Created Folder Node:", folder_node)
        elif node["type"] == "file":
            file_node = await create_file_node(
                session, node["name"], node["path"], node["extension"], node["parent_path"]
            )
            print("Created File Node:", file_node)
await driver.close()
# Out:
# Created Repository Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:200' labels=frozenset({'Repository'}) properties={'name': 'sec-insights'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:0' labels=frozenset({'Folder'}) properties={'path': '.devcontainer', 'name': '.devcontainer'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:1' labels=frozenset({'File'}) properties={'path': '.devcontainer/Dockerfile', 'extension': '', 'name': 'Dockerfile'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:2' labels=frozenset({'File'}) properties={'path': '.devcontainer/README.md', 'extension': 'md', 'name': 'README.md'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:3' labels=frozenset({'File'}) properties={'path': '.devcontainer/devcontainer.json', 'extension': 'json', 'name': 'devcontainer.json'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:4' labels=frozenset({'File'}) properties={'path': '.devcontainer/post_create_command.sh', 'extension': 'sh', 'name': 'post_create_command.sh'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:5' labels=frozenset({'File'}) properties={'path': 'FAQ.md', 'extension': 'md', 'name': 'FAQ.md'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:6' labels=frozenset({'File'}) properties={'path': 'LICENSE', 'extension': '', 'name': 'LICENSE'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:7' labels=frozenset({'File'}) properties={'path': 'README.md', 'extension': 'md', 'name': 'README.md'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:8' labels=frozenset({'Folder'}) properties={'path': 'backend', 'name': 'backend'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:9' labels=frozenset({'File'}) properties={'path': 'backend/.env.development', 'extension': 'development', 'name': '.env.development'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:10' labels=frozenset({'File'}) properties={'path': 'backend/.env.docker', 'extension': 'docker', 'name': '.env.docker'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:11' labels=frozenset({'File'}) properties={'path': 'backend/.flake8', 'extension': '', 'name': '.flake8'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:12' labels=frozenset({'File'}) properties={'path': 'backend/.gitignore', 'extension': '', 'name': '.gitignore'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:13' labels=frozenset({'File'}) properties={'path': 'backend/.pylintrc', 'extension': '', 'name': '.pylintrc'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:14' labels=frozenset({'File'}) properties={'path': 'backend/.python-version', 'extension': '', 'name': '.python-version'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:15' labels=frozenset({'Folder'}) properties={'path': 'backend/.vscode', 'name': '.vscode'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:16' labels=frozenset({'File'}) properties={'path': 'backend/.vscode/settings.json', 'extension': 'json', 'name': 'settings.json'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:17' labels=frozenset({'File'}) properties={'path': 'backend/Dockerfile', 'extension': '', 'name': 'Dockerfile'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:18' labels=frozenset({'File'}) properties={'path': 'backend/Makefile', 'extension': '', 'name': 'Makefile'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:19' labels=frozenset({'File'}) properties={'path': 'backend/README.md', 'extension': 'md', 'name': 'README.md'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:20' labels=frozenset({'File'}) properties={'path': 'backend/alembic.ini', 'extension': 'ini', 'name': 'alembic.ini'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:21' labels=frozenset({'Folder'}) properties={'path': 'backend/alembic', 'name': 'alembic'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:22' labels=frozenset({'File'}) properties={'path': 'backend/alembic/README', 'extension': '', 'name': 'README'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:23' labels=frozenset({'File'}) properties={'path': 'backend/alembic/env.py', 'extension': 'py', 'name': 'env.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:24' labels=frozenset({'File'}) properties={'path': 'backend/alembic/script.py.mako', 'extension': 'mako', 'name': 'script.py.mako'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:25' labels=frozenset({'Folder'}) properties={'path': 'backend/alembic/versions', 'name': 'versions'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:26' labels=frozenset({'File'}) properties={'path': 'backend/alembic/versions/1b0b616e08c6_replace_value_within_.py', 'extension': 'py', 'name': '1b0b616e08c6_replace_value_within_.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:27' labels=frozenset({'File'}) properties={'path': 'backend/alembic/versions/477cee72edc4_init_tables.py', 'extension': 'py', 'name': '477cee72edc4_init_tables.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:28' labels=frozenset({'File'}) properties={'path': 'backend/alembic/versions/663b3fea3024_update_sub_process_columns.py', 'extension': 'py', 'name': '663b3fea3024_update_sub_process_columns.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:29' labels=frozenset({'File'}) properties={'path': 'backend/alembic/versions/873c0c4616ea_add_foreign_key_indices.py', 'extension': 'py', 'name': '873c0c4616ea_add_foreign_key_indices.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:30' labels=frozenset({'File'}) properties={'path': 'backend/alembic/versions/90a1d6a26343_create_doc_tables.py', 'extension': 'py', 'name': '90a1d6a26343_create_doc_tables.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:31' labels=frozenset({'File'}) properties={'path': 'backend/alembic/versions/c008bb4f3f48_update_sub_process_columns.py', 'extension': 'py', 'name': 'c008bb4f3f48_update_sub_process_columns.py'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:32' labels=frozenset({'Folder'}) properties={'path': 'backend/app', 'name': 'app'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:33' labels=frozenset({'File'}) properties={'path': 'backend/app/__init__.py', 'extension': 'py', 'name': '__init__.py'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:34' labels=frozenset({'Folder'}) properties={'path': 'backend/app/api', 'name': 'api'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:35' labels=frozenset({'File'}) properties={'path': 'backend/app/api/__init__.py', 'extension': 'py', 'name': '__init__.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:36' labels=frozenset({'File'}) properties={'path': 'backend/app/api/api.py', 'extension': 'py', 'name': 'api.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:37' labels=frozenset({'File'}) properties={'path': 'backend/app/api/crud.py', 'extension': 'py', 'name': 'crud.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:38' labels=frozenset({'File'}) properties={'path': 'backend/app/api/deps.py', 'extension': 'py', 'name': 'deps.py'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:39' labels=frozenset({'Folder'}) properties={'path': 'backend/app/api/endpoints', 'name': 'endpoints'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:40' labels=frozenset({'File'}) properties={'path': 'backend/app/api/endpoints/__init__.py', 'extension': 'py', 'name': '__init__.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:41' labels=frozenset({'File'}) properties={'path': 'backend/app/api/endpoints/conversation.py', 'extension': 'py', 'name': 'conversation.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:42' labels=frozenset({'File'}) properties={'path': 'backend/app/api/endpoints/documents.py', 'extension': 'py', 'name': 'documents.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:43' labels=frozenset({'File'}) properties={'path': 'backend/app/api/endpoints/health.py', 'extension': 'py', 'name': 'health.py'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:44' labels=frozenset({'Folder'}) properties={'path': 'backend/app/chat', 'name': 'chat'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:45' labels=frozenset({'File'}) properties={'path': 'backend/app/chat/__init__.py', 'extension': 'py', 'name': '__init__.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:46' labels=frozenset({'File'}) properties={'path': 'backend/app/chat/constants.py', 'extension': 'py', 'name': 'constants.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:47' labels=frozenset({'File'}) properties={'path': 'backend/app/chat/engine.py', 'extension': 'py', 'name': 'engine.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:48' labels=frozenset({'File'}) properties={'path': 'backend/app/chat/messaging.py', 'extension': 'py', 'name': 'messaging.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:49' labels=frozenset({'File'}) properties={'path': 'backend/app/chat/pg_vector.py', 'extension': 'py', 'name': 'pg_vector.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:50' labels=frozenset({'File'}) properties={'path': 'backend/app/chat/qa_response_synth.py', 'extension': 'py', 'name': 'qa_response_synth.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:51' labels=frozenset({'File'}) properties={'path': 'backend/app/chat/tools.py', 'extension': 'py', 'name': 'tools.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:52' labels=frozenset({'File'}) properties={'path': 'backend/app/chat/utils.py', 'extension': 'py', 'name': 'utils.py'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:53' labels=frozenset({'Folder'}) properties={'path': 'backend/app/core', 'name': 'core'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:54' labels=frozenset({'File'}) properties={'path': 'backend/app/core/__init__.py', 'extension': 'py', 'name': '__init__.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:55' labels=frozenset({'File'}) properties={'path': 'backend/app/core/config.py', 'extension': 'py', 'name': 'config.py'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:56' labels=frozenset({'Folder'}) properties={'path': 'backend/app/db', 'name': 'db'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:57' labels=frozenset({'File'}) properties={'path': 'backend/app/db/base.py', 'extension': 'py', 'name': 'base.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:58' labels=frozenset({'File'}) properties={'path': 'backend/app/db/session.py', 'extension': 'py', 'name': 'session.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:59' labels=frozenset({'File'}) properties={'path': 'backend/app/db/wait_for_db.py', 'extension': 'py', 'name': 'wait_for_db.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:60' labels=frozenset({'File'}) properties={'path': 'backend/app/loader_io.py', 'extension': 'py', 'name': 'loader_io.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:61' labels=frozenset({'File'}) properties={'path': 'backend/app/main.py', 'extension': 'py', 'name': 'main.py'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:62' labels=frozenset({'Folder'}) properties={'path': 'backend/app/models', 'name': 'models'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:63' labels=frozenset({'File'}) properties={'path': 'backend/app/models/__init__.py', 'extension': 'py', 'name': '__init__.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:64' labels=frozenset({'File'}) properties={'path': 'backend/app/models/base.py', 'extension': 'py', 'name': 'base.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:65' labels=frozenset({'File'}) properties={'path': 'backend/app/models/db.py', 'extension': 'py', 'name': 'db.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:66' labels=frozenset({'File'}) properties={'path': 'backend/app/schema.py', 'extension': 'py', 'name': 'schema.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:67' labels=frozenset({'File'}) properties={'path': 'backend/docker-compose.yml', 'extension': 'yml', 'name': 'docker-compose.yml'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:68' labels=frozenset({'File'}) properties={'path': 'backend/localstack-cors-config.json', 'extension': 'json', 'name': 'localstack-cors-config.json'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:69' labels=frozenset({'File'}) properties={'path': 'backend/poetry.lock', 'extension': 'lock', 'name': 'poetry.lock'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:70' labels=frozenset({'File'}) properties={'path': 'backend/pyproject.toml', 'extension': 'toml', 'name': 'pyproject.toml'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:71' labels=frozenset({'Folder'}) properties={'path': 'backend/scripts', 'name': 'scripts'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:72' labels=frozenset({'File'}) properties={'path': 'backend/scripts/build_vector_tables.py', 'extension': 'py', 'name': 'build_vector_tables.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:73' labels=frozenset({'File'}) properties={'path': 'backend/scripts/chat_llama.py', 'extension': 'py', 'name': 'chat_llama.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:74' labels=frozenset({'File'}) properties={'path': 'backend/scripts/dedupe_vector_store.py', 'extension': 'py', 'name': 'dedupe_vector_store.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:75' labels=frozenset({'File'}) properties={'path': 'backend/scripts/download_sec_pdf.py', 'extension': 'py', 'name': 'download_sec_pdf.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:76' labels=frozenset({'File'}) properties={'path': 'backend/scripts/file_utils.py', 'extension': 'py', 'name': 'file_utils.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:77' labels=frozenset({'File'}) properties={'path': 'backend/scripts/seed_db.py', 'extension': 'py', 'name': 'seed_db.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:78' labels=frozenset({'File'}) properties={'path': 'backend/scripts/seed_storage_context.py', 'extension': 'py', 'name': 'seed_storage_context.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:79' labels=frozenset({'File'}) properties={'path': 'backend/scripts/stock_utils.py', 'extension': 'py', 'name': 'stock_utils.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:80' labels=frozenset({'File'}) properties={'path': 'backend/scripts/upsert_db_sec_documents.py', 'extension': 'py', 'name': 'upsert_db_sec_documents.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:81' labels=frozenset({'File'}) properties={'path': 'backend/scripts/upsert_document.py', 'extension': 'py', 'name': 'upsert_document.py'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:82' labels=frozenset({'Folder'}) properties={'path': 'backend/tests', 'name': 'tests'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:83' labels=frozenset({'Folder'}) properties={'path': 'backend/tests/app', 'name': 'app'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:84' labels=frozenset({'Folder'}) properties={'path': 'backend/tests/app/chat', 'name': 'chat'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:85' labels=frozenset({'File'}) properties={'path': 'backend/tests/app/chat/test_engine.py', 'extension': 'py', 'name': 'test_engine.py'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:86' labels=frozenset({'File'}) properties={'path': 'backend/troubleshooting.md', 'extension': 'md', 'name': 'troubleshooting.md'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:87' labels=frozenset({'Folder'}) properties={'path': 'frontend', 'name': 'frontend'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:88' labels=frozenset({'Folder'}) properties={'path': 'frontend/.devcontainer', 'name': '.devcontainer'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:89' labels=frozenset({'File'}) properties={'path': 'frontend/.devcontainer/devcontainer.json', 'extension': 'json', 'name': 'devcontainer.json'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:90' labels=frozenset({'File'}) properties={'path': 'frontend/.env.example', 'extension': 'example', 'name': '.env.example'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:91' labels=frozenset({'File'}) properties={'path': 'frontend/.eslintrc.cjs', 'extension': 'cjs', 'name': '.eslintrc.cjs'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:92' labels=frozenset({'File'}) properties={'path': 'frontend/.gitignore', 'extension': '', 'name': '.gitignore'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:93' labels=frozenset({'File'}) properties={'path': 'frontend/README.md', 'extension': 'md', 'name': 'README.md'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:94' labels=frozenset({'File'}) properties={'path': 'frontend/next.config.mjs', 'extension': 'mjs', 'name': 'next.config.mjs'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:95' labels=frozenset({'File'}) properties={'path': 'frontend/package-lock.json', 'extension': 'json', 'name': 'package-lock.json'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:96' labels=frozenset({'File'}) properties={'path': 'frontend/package.json', 'extension': 'json', 'name': 'package.json'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:97' labels=frozenset({'File'}) properties={'path': 'frontend/postcss.config.cjs', 'extension': 'cjs', 'name': 'postcss.config.cjs'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:98' labels=frozenset({'File'}) properties={'path': 'frontend/prettier.config.cjs', 'extension': 'cjs', 'name': 'prettier.config.cjs'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:99' labels=frozenset({'Folder'}) properties={'path': 'frontend/public', 'name': 'public'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:100' labels=frozenset({'File'}) properties={'path': 'frontend/public/Gradient.png', 'extension': 'png', 'name': 'Gradient.png'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:101' labels=frozenset({'File'}) properties={'path': 'frontend/public/chat-1.svg', 'extension': 'svg', 'name': 'chat-1.svg'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:102' labels=frozenset({'File'}) properties={'path': 'frontend/public/chat-2.svg', 'extension': 'svg', 'name': 'chat-2.svg'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:103' labels=frozenset({'File'}) properties={'path': 'frontend/public/chat-3.svg', 'extension': 'svg', 'name': 'chat-3.svg'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:104' labels=frozenset({'File'}) properties={'path': 'frontend/public/chat-4.svg', 'extension': 'svg', 'name': 'chat-4.svg'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:105' labels=frozenset({'File'}) properties={'path': 'frontend/public/chat-5.svg', 'extension': 'svg', 'name': 'chat-5.svg'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:106' labels=frozenset({'File'}) properties={'path': 'frontend/public/citations.svg', 'extension': 'svg', 'name': 'citations.svg'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:107' labels=frozenset({'File'}) properties={'path': 'frontend/public/doc-selector-no-highlight.svg', 'extension': 'svg', 'name': 'doc-selector-no-highlight.svg'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:108' labels=frozenset({'File'}) properties={'path': 'frontend/public/docs-with-highlight.svg', 'extension': 'svg', 'name': 'docs-with-highlight.svg'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:109' labels=frozenset({'File'}) properties={'path': 'frontend/public/favicon.ico', 'extension': 'ico', 'name': 'favicon.ico'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:110' labels=frozenset({'File'}) properties={'path': 'frontend/public/full-chat.png', 'extension': 'png', 'name': 'full-chat.png'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:111' labels=frozenset({'File'}) properties={'path': 'frontend/public/full-chat.svg', 'extension': 'svg', 'name': 'full-chat.svg'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:112' labels=frozenset({'File'}) properties={'path': 'frontend/public/highlight-1.svg', 'extension': 'svg', 'name': 'highlight-1.svg'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:113' labels=frozenset({'File'}) properties={'path': 'frontend/public/highlight-2.svg', 'extension': 'svg', 'name': 'highlight-2.svg'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:114' labels=frozenset({'File'}) properties={'path': 'frontend/public/highlight-3.svg', 'extension': 'svg', 'name': 'highlight-3.svg'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:115' labels=frozenset({'File'}) properties={'path': 'frontend/public/highlight-4.svg', 'extension': 'svg', 'name': 'highlight-4.svg'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:116' labels=frozenset({'File'}) properties={'path': 'frontend/public/logo-black.svg', 'extension': 'svg', 'name': 'logo-black.svg'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:117' labels=frozenset({'File'}) properties={'path': 'frontend/public/logo-white.svg', 'extension': 'svg', 'name': 'logo-white.svg'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:118' labels=frozenset({'File'}) properties={'path': 'frontend/public/lyft-2021-10k.pdf', 'extension': 'pdf', 'name': 'lyft-2021-10k.pdf'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:119' labels=frozenset({'File'}) properties={'path': 'frontend/public/multi-doc-1.svg', 'extension': 'svg', 'name': 'multi-doc-1.svg'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:120' labels=frozenset({'File'}) properties={'path': 'frontend/public/multi-doc-2.svg', 'extension': 'svg', 'name': 'multi-doc-2.svg'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:121' labels=frozenset({'File'}) properties={'path': 'frontend/public/multi-doc-3.svg', 'extension': 'svg', 'name': 'multi-doc-3.svg'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:122' labels=frozenset({'File'}) properties={'path': 'frontend/public/multi-doc-4.svg', 'extension': 'svg', 'name': 'multi-doc-4.svg'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:123' labels=frozenset({'File'}) properties={'path': 'frontend/public/uber-2021-10k.pdf', 'extension': 'pdf', 'name': 'uber-2021-10k.pdf'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:124' labels=frozenset({'File'}) properties={'path': 'frontend/sentry.client.config.ts', 'extension': 'ts', 'name': 'sentry.client.config.ts'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:125' labels=frozenset({'File'}) properties={'path': 'frontend/sentry.edge.config.ts', 'extension': 'ts', 'name': 'sentry.edge.config.ts'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:126' labels=frozenset({'File'}) properties={'path': 'frontend/sentry.server.config.ts', 'extension': 'ts', 'name': 'sentry.server.config.ts'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:127' labels=frozenset({'Folder'}) properties={'path': 'frontend/src', 'name': 'src'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:128' labels=frozenset({'Folder'}) properties={'path': 'frontend/src/api', 'name': 'api'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:129' labels=frozenset({'File'}) properties={'path': 'frontend/src/api/backend.tsx', 'extension': 'tsx', 'name': 'backend.tsx'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:130' labels=frozenset({'Folder'}) properties={'path': 'frontend/src/api/utils', 'name': 'utils'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:131' labels=frozenset({'File'}) properties={'path': 'frontend/src/api/utils/documents.tsx', 'extension': 'tsx', 'name': 'documents.tsx'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:132' labels=frozenset({'Folder'}) properties={'path': 'frontend/src/components', 'name': 'components'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:133' labels=frozenset({'File'}) properties={'path': 'frontend/src/components/Layout.tsx', 'extension': 'tsx', 'name': 'Layout.tsx'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:134' labels=frozenset({'Folder'}) properties={'path': 'frontend/src/components/basics', 'name': 'basics'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:135' labels=frozenset({'File'}) properties={'path': 'frontend/src/components/basics/Loading.tsx', 'extension': 'tsx', 'name': 'Loading.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:136' labels=frozenset({'File'}) properties={'path': 'frontend/src/components/basics/Modal.tsx', 'extension': 'tsx', 'name': 'Modal.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:137' labels=frozenset({'File'}) properties={'path': 'frontend/src/components/basics/ModalPortal.tsx', 'extension': 'tsx', 'name': 'ModalPortal.tsx'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:138' labels=frozenset({'Folder'}) properties={'path': 'frontend/src/components/conversations', 'name': 'conversations'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:139' labels=frozenset({'File'}) properties={'path': 'frontend/src/components/conversations/RenderConversations.tsx', 'extension': 'tsx', 'name': 'RenderConversations.tsx'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:140' labels=frozenset({'Folder'}) properties={'path': 'frontend/src/components/landing-page', 'name': 'landing-page'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:141' labels=frozenset({'File'}) properties={'path': 'frontend/src/components/landing-page/AnimateSvg.tsx', 'extension': 'tsx', 'name': 'AnimateSvg.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:142' labels=frozenset({'File'}) properties={'path': 'frontend/src/components/landing-page/MarketingSection.tsx', 'extension': 'tsx', 'name': 'MarketingSection.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:143' labels=frozenset({'File'}) properties={'path': 'frontend/src/components/landing-page/SelectTicker.tsx', 'extension': 'tsx', 'name': 'SelectTicker.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:144' labels=frozenset({'File'}) properties={'path': 'frontend/src/components/landing-page/TitleAndDropdown.tsx', 'extension': 'tsx', 'name': 'TitleAndDropdown.tsx'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:145' labels=frozenset({'Folder'}) properties={'path': 'frontend/src/components/modals', 'name': 'modals'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:146' labels=frozenset({'File'}) properties={'path': 'frontend/src/components/modals/ShareLinkModal.tsx', 'extension': 'tsx', 'name': 'ShareLinkModal.tsx'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:147' labels=frozenset({'Folder'}) properties={'path': 'frontend/src/components/pdf-viewer', 'name': 'pdf-viewer'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:148' labels=frozenset({'File'}) properties={'path': 'frontend/src/components/pdf-viewer/DisplayMultiplePdfs.tsx', 'extension': 'tsx', 'name': 'DisplayMultiplePdfs.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:149' labels=frozenset({'File'}) properties={'path': 'frontend/src/components/pdf-viewer/PdfOptionsBar.tsx', 'extension': 'tsx', 'name': 'PdfOptionsBar.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:150' labels=frozenset({'File'}) properties={'path': 'frontend/src/components/pdf-viewer/ViewPdf.tsx', 'extension': 'tsx', 'name': 'ViewPdf.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:151' labels=frozenset({'File'}) properties={'path': 'frontend/src/components/pdf-viewer/VirtualizedPdf.tsx', 'extension': 'tsx', 'name': 'VirtualizedPdf.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:152' labels=frozenset({'File'}) properties={'path': 'frontend/src/components/pdf-viewer/pdfDisplayConstants.tsx', 'extension': 'tsx', 'name': 'pdfDisplayConstants.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:153' labels=frozenset({'File'}) properties={'path': 'frontend/src/config.js', 'extension': 'js', 'name': 'config.js'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:154' labels=frozenset({'File'}) properties={'path': 'frontend/src/constants.tsx', 'extension': 'tsx', 'name': 'constants.tsx'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:155' labels=frozenset({'Folder'}) properties={'path': 'frontend/src/context', 'name': 'context'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:156' labels=frozenset({'File'}) properties={'path': 'frontend/src/context/pdf.tsx', 'extension': 'tsx', 'name': 'pdf.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:157' labels=frozenset({'File'}) properties={'path': 'frontend/src/env.mjs', 'extension': 'mjs', 'name': 'env.mjs'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:158' labels=frozenset({'Folder'}) properties={'path': 'frontend/src/hooks', 'name': 'hooks'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:159' labels=frozenset({'File'}) properties={'path': 'frontend/src/hooks/useDocumentSelector.tsx', 'extension': 'tsx', 'name': 'useDocumentSelector.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:160' labels=frozenset({'File'}) properties={'path': 'frontend/src/hooks/useMessages.tsx', 'extension': 'tsx', 'name': 'useMessages.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:161' labels=frozenset({'File'}) properties={'path': 'frontend/src/hooks/useMultiplePdfs.tsx', 'extension': 'tsx', 'name': 'useMultiplePdfs.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:162' labels=frozenset({'File'}) properties={'path': 'frontend/src/hooks/usePdfViewer.tsx', 'extension': 'tsx', 'name': 'usePdfViewer.tsx'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:163' labels=frozenset({'Folder'}) properties={'path': 'frontend/src/hooks/utils', 'name': 'utils'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:164' labels=frozenset({'File'}) properties={'path': 'frontend/src/hooks/utils/useFocus.tsx', 'extension': 'tsx', 'name': 'useFocus.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:165' labels=frozenset({'File'}) properties={'path': 'frontend/src/hooks/utils/useIsMobile.tsx', 'extension': 'tsx', 'name': 'useIsMobile.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:166' labels=frozenset({'File'}) properties={'path': 'frontend/src/hooks/utils/useLocalStorage.ts', 'extension': 'ts', 'name': 'useLocalStorage.ts'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:167' labels=frozenset({'File'}) properties={'path': 'frontend/src/hooks/utils/useModal.tsx', 'extension': 'tsx', 'name': 'useModal.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:168' labels=frozenset({'File'}) properties={'path': 'frontend/src/hooks/utils/useScrollBreakpoint.tsx', 'extension': 'tsx', 'name': 'useScrollBreakpoint.tsx'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:169' labels=frozenset({'Folder'}) properties={'path': 'frontend/src/modules', 'name': 'modules'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:170' labels=frozenset({'File'}) properties={'path': 'frontend/src/modules/react-pdf.d.ts', 'extension': 'ts', 'name': 'react-pdf.d.ts'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:171' labels=frozenset({'Folder'}) properties={'path': 'frontend/src/pages', 'name': 'pages'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:172' labels=frozenset({'File'}) properties={'path': 'frontend/src/pages/_app.tsx', 'extension': 'tsx', 'name': '_app.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:173' labels=frozenset({'File'}) properties={'path': 'frontend/src/pages/_document.tsx', 'extension': 'tsx', 'name': '_document.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:174' labels=frozenset({'File'}) properties={'path': 'frontend/src/pages/_error.tsx', 'extension': 'tsx', 'name': '_error.tsx'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:175' labels=frozenset({'Folder'}) properties={'path': 'frontend/src/pages/conversation', 'name': 'conversation'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:176' labels=frozenset({'File'}) properties={'path': 'frontend/src/pages/conversation/[id].tsx', 'extension': 'tsx', 'name': '[id].tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:177' labels=frozenset({'File'}) properties={'path': 'frontend/src/pages/index.tsx', 'extension': 'tsx', 'name': 'index.tsx'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:178' labels=frozenset({'Folder'}) properties={'path': 'frontend/src/styles', 'name': 'styles'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:179' labels=frozenset({'File'}) properties={'path': 'frontend/src/styles/globals.css', 'extension': 'css', 'name': 'globals.css'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:180' labels=frozenset({'File'}) properties={'path': 'frontend/src/styles/react-select.tsx', 'extension': 'tsx', 'name': 'react-select.tsx'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:181' labels=frozenset({'Folder'}) properties={'path': 'frontend/src/svgs', 'name': 'svgs'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:182' labels=frozenset({'File'}) properties={'path': 'frontend/src/svgs/llama.tsx', 'extension': 'tsx', 'name': 'llama.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:183' labels=frozenset({'File'}) properties={'path': 'frontend/src/svgs/right-arrow.tsx', 'extension': 'tsx', 'name': 'right-arrow.tsx'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:184' labels=frozenset({'Folder'}) properties={'path': 'frontend/src/types', 'name': 'types'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:185' labels=frozenset({'Folder'}) properties={'path': 'frontend/src/types/backend', 'name': 'backend'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:186' labels=frozenset({'File'}) properties={'path': 'frontend/src/types/backend/document.tsx', 'extension': 'tsx', 'name': 'document.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:187' labels=frozenset({'File'}) properties={'path': 'frontend/src/types/conversation.tsx', 'extension': 'tsx', 'name': 'conversation.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:188' labels=frozenset({'File'}) properties={'path': 'frontend/src/types/document.tsx', 'extension': 'tsx', 'name': 'document.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:189' labels=frozenset({'File'}) properties={'path': 'frontend/src/types/selection.tsx', 'extension': 'tsx', 'name': 'selection.tsx'}>
# Created Folder Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:190' labels=frozenset({'Folder'}) properties={'path': 'frontend/src/utils', 'name': 'utils'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:191' labels=frozenset({'File'}) properties={'path': 'frontend/src/utils/colors.tsx', 'extension': 'tsx', 'name': 'colors.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:192' labels=frozenset({'File'}) properties={'path': 'frontend/src/utils/documents.tsx', 'extension': 'tsx', 'name': 'documents.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:193' labels=frozenset({'File'}) properties={'path': 'frontend/src/utils/landing-page-selection.tsx', 'extension': 'tsx', 'name': 'landing-page-selection.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:194' labels=frozenset({'File'}) properties={'path': 'frontend/src/utils/multi-line-highlight.tsx', 'extension': 'tsx', 'name': 'multi-line-highlight.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:195' labels=frozenset({'File'}) properties={'path': 'frontend/src/utils/timezone.tsx', 'extension': 'tsx', 'name': 'timezone.tsx'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:196' labels=frozenset({'File'}) properties={'path': 'frontend/tailwind.config.ts', 'extension': 'ts', 'name': 'tailwind.config.ts'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:197' labels=frozenset({'File'}) properties={'path': 'frontend/tsconfig.json', 'extension': 'json', 'name': 'tsconfig.json'}>
# Created File Node: <Node element_id='4:80166c63-cba2-410b-85d0-b8a3f32d747a:198' labels=frozenset({'File'}) properties={'path': 'render.yaml', 'extension': 'yaml', 'name': 'render.yaml'}>
